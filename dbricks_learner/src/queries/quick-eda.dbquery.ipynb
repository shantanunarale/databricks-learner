-- %%
SHOW SCHEMAS;
USE SCHEMA v01;
SHOW VOLUMES;

LIST '/Volumes/databricks_simulated_retail_customer_data/v01/retail-pipeline';
LIST '/Volumes/databricks_simulated_retail_customer_data/v01/source_files';

SELECT * 
FROM text.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv`;

SELECT * 
FROM csv.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv` WITH (header=true);


SELECT cast(from_unixtime(valid_from) as date) 
FROM csv.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv` WITH (header=true);

SELECT COUNT(1) FROM text.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales.csv`;

SELECT * 
FROM csv.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales.csv` WITH (header=true, quote='"', escape='"');

SELECT COUNT(1)
FROM text.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales_orders.csv`;

SELECT *
FROM csv.`/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales_orders.csv`
WITH (header=true, quote='"', escape='"');
