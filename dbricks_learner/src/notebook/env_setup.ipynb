-- %%
USE CATALOG IDENTIFIER(:catalog_name);

-- %%
CREATE SCHEMA IF NOT EXISTS `landing`;
CREATE SCHEMA IF NOT EXISTS `bronze`;
CREATE SCHEMA IF NOT EXISTS `silver`;
CREATE SCHEMA IF NOT EXISTS `gold`;

-- %%
%python
account_name = dbutils.widgets.get("account_name")
url = f"abfss://external@{account_name}.dfs.core.windows.net/"
url
spark.sql(f"""
          CREATE EXTERNAL LOCATION IF NOT EXISTS `landing_location`
          URL '{url}'
          WITH (STORAGE CREDENTIAL scexternal)
          """)

-- %%
%python
spark.sql(f"""
          CREATE EXTERNAL VOLUME landing.retail_raw
          LOCATION '{url}/retail_landing'
          """)
